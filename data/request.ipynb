# %%
import requests

r = requests.get(url="http://127.0.0.1:5000/predict/?code=AAA")

print(r.text)
# Out:
# {
#   "data": [
#     {
#       "Actual Price": 8.2,
#       "Predicted Price": 7.953552722930908,
#       "date": "2022-10-14"
#     },
#     {
#       "Actual Price": 8.2,
#       "Predicted Price": 8.138557434082031,
#       "date": "2022-10-17"
#     },
#     {
#       "Actual Price": 8.32,
#       "Predicted Price": 8.21630859375,
#       "date": "2022-10-18"
#     },
#     {
#       "Actual Price": 8.34,
#       "Predicted Price": 8.313549041748047,
#       "date": "2022-10-19"
#     },
#     {
#       "Actual Price": 8.3,
#       "Predicted Price": 8.373533248901367,
#       "date": "2022-10-20"
#     },
#     {
#       "Actual Price": 8.15,
#       "Predicted Price": 8.380605697631836,
#       "date": "2022-10-21"
#     },
#     {
#       "Actual Price": 7.61,
#       "Predicted Price": 8.295890808105469,
#       "date": "2022-10-24"
#     },
#     {
#       "Actual Price": 7.06,
#       "Predicted Price": 7.929154396057129,
#       "date": "2022-10-25"
#     },
#     {
# ...
